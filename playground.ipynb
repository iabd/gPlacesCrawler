# %%
import json, urllib, os, functools, time

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
key="AIzaSyASmGMElEZthlsMGEN-p3Nw1NInctWoXTk"
fields="name,rating,reviews"

# %%
test=pd.read_csv('crawlCommunes.csv')

# %%
def getReviewers(placeIDs, fields, key):
    reviewersList=[]
    for idx, placeID in enumerate(placeIDs):
        print("\r{} / {}".format(idx, len(placeIDs)), end='')
        tempReviewers=[]
        url="https://maps.googleapis.com/maps/api/place/details/json?placeid={}&fields={}&key={}".format(placeID, fields, key)
        response = urllib.request.urlopen(url).read()
        jsonResponse = json.loads(response.decode('utf-8'))
        result = jsonResponse['result']
        try: 
            reviewersTemp=[temp['author_name'] for temp in result['reviews']]
            for temp in reviewersTemp:
                tempReviewers.extend(temp.split())
            reviewersList.append(tempReviewers)
        except:
            reviewersList.append(['Mr. Hoodoo'])
    return reviewersList

# %%
reviewers= getReviewers(testt.place_id, fields, key)
# Out:
# 325 / 5194

# %%
for idx, value in enumerate(reviewers):
    testt.reviewers[idx]=value
# Out:
# /Users/abd/miniconda3/envs/python37/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
testt=testt.drop(['reviewers'], axis=1)

# %%
testt
# Out:
#       Unnamed: 0                                           geometry  \
# 0              0  {'location': {'lat': 41.8976265, 'lng': 12.513...
# 1              1  {'location': {'lat': 41.8904183, 'lng': 12.503...
# 2              2  {'location': {'lat': 41.8992909, 'lng': 12.499...
# 3              3  {'location': {'lat': 41.89478889999999, 'lng':...
# 4              4  {'location': {'lat': 41.8932739, 'lng': 12.515...
# 5              5  {'location': {'lat': 41.8862406, 'lng': 12.517...
# 6              6  {'location': {'lat': 41.9005571, 'lng': 12.513...
# 7              7  {'location': {'lat': 41.8916802, 'lng': 12.513...
# 8              8  {'location': {'lat': 41.8997168, 'lng': 12.517...
# 9              9  {'location': {'lat': 41.9001194, 'lng': 12.517...
# 10            10  {'location': {'lat': 41.8830399, 'lng': 12.514...
# 11            11  {'location': {'lat': 41.89725139999999, 'lng':...
# 12            12  {'location': {'lat': 41.8950848, 'lng': 12.515...
# ...

# %%
zz=list(tempX.columns)

# %%
z={"name", "rating"}

# %%
sub = [temp for temp in list(tempX.columns) if temp not in z]

# %%
sub
# Out:
# ['reviews']

# %%
for temp in result['reviews']:
    print (temp['author_name'])
# Out:
# Ivan Bisogni
# aldo minniti
# Saverio Davide Mascolo
# Luciano Mazzeo
# madlockz millo

# %%
reviewers=[temp['author_name'] for temp in result['reviews']]

# %%
temp = pd.read_csv('../SNA-Project/pisaList.csv')

# %%
temp2=[]
for temp in reviewers:
    print(temp.split())
    temp2.extend(temp.split())
# Out:
# ['Ivan', 'Bisogni']
# ['aldo', 'minniti']
# ['Saverio', 'Davide', 'Mascolo']
# ['Luciano', 'Mazzeo']
# ['madlockz', 'millo']

# %%
for temp in reviewers:
    tmep2.extennd

# %%
testt=pd.read_csv('tempClean.csv')

# %%
testt
# Out:
#       Unnamed: 0                                           geometry  \
# 0              0  {'location': {'lat': 41.8976265, 'lng': 12.513...
# 1              1  {'location': {'lat': 41.8904183, 'lng': 12.503...
# 2              2  {'location': {'lat': 41.8992909, 'lng': 12.499...
# 3              3  {'location': {'lat': 41.89478889999999, 'lng':...
# 4              4  {'location': {'lat': 41.8932739, 'lng': 12.515...
# 5              5  {'location': {'lat': 41.8862406, 'lng': 12.517...
# 6              6  {'location': {'lat': 41.9005571, 'lng': 12.513...
# 7              7  {'location': {'lat': 41.8916802, 'lng': 12.513...
# 8              8  {'location': {'lat': 41.8997168, 'lng': 12.517...
# 9              9  {'location': {'lat': 41.9001194, 'lng': 12.517...
# 10            10  {'location': {'lat': 41.8830399, 'lng': 12.514...
# 11            11  {'location': {'lat': 41.89725139999999, 'lng':...
# 12            12  {'location': {'lat': 41.8950848, 'lng': 12.515...
# ...

# %%
test2=pd.read_csv('crawlCities.csv')

# %%
test2=pd.read_csv('italyCities.csv')

# %%
locList=list(test2.cods)

# %%
import time
